# %% [markdown]
# <a href="https://colab.research.google.com/github/madshjorth-andersen/Udrykning-og-beredskab/blob/main/v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Udrykning og beredskab

# %%
import random
import pandas as pd

antal_biler = 20
uden_alarm = antal_biler // 2
med_alarm = antal_biler // 2

uden_alarm_reaktionstid = [random.randint(5, 20) for _ in range(uden_alarm)]
med_alarm_reaktionstid = [random.randint(15, 30) for _ in range(med_alarm)]

def forsinkelse_chance(reaktionstid, bilnummer):
    if reaktionstid > 25:
        resultat = "Forsinker ikke udrykningskøretøjet"
        chance = 0  # 0% chance for forsinkelse
    elif reaktionstid < 10:
        resultat = "Forsinker køretøjet"
        chance = 100  # 100% chance for forsinkelse
    else:
        resultat = "Chance for forsinkelse"
        chance = int((25 - reaktionstid) / 15 * 100)

    print(f"Bil {bilnummer}: reaktionstid {reaktionstid} - {resultat} ({chance}% chance for forsinkelse)")
    return chance

# Lister til at gemme forsinkelsesdata
forsinkelser_uden_alarm = []
for i, tid in enumerate(uden_alarm_reaktionstid):
    forsinkelser_uden_alarm.append(forsinkelse_chance(tid, i + 1))

forsinkelser_med_alarm = []
for i, tid in enumerate(med_alarm_reaktionstid):
    forsinkelser_med_alarm.append(forsinkelse_chance(tid, i + uden_alarm + 1))

print("Forsinkelser uden alarm:", forsinkelser_uden_alarm)
print("Forsinkelser med alarm:", forsinkelser_med_alarm)
# Out:
# Bil 1: reaktionstid 18 - Chance for forsinkelse (46% chance for forsinkelse)
# Bil 2: reaktionstid 20 - Chance for forsinkelse (33% chance for forsinkelse)
# Bil 3: reaktionstid 10 - Chance for forsinkelse (100% chance for forsinkelse)
# Bil 4: reaktionstid 20 - Chance for forsinkelse (33% chance for forsinkelse)
# Bil 5: reaktionstid 14 - Chance for forsinkelse (73% chance for forsinkelse)
# Bil 6: reaktionstid 12 - Chance for forsinkelse (86% chance for forsinkelse)
# Bil 7: reaktionstid 15 - Chance for forsinkelse (66% chance for forsinkelse)
# Bil 8: reaktionstid 8 - Forsinker køretøjet (100% chance for forsinkelse)
# Bil 9: reaktionstid 15 - Chance for forsinkelse (66% chance for forsinkelse)
# Bil 10: reaktionstid 20 - Chance for forsinkelse (33% chance for forsinkelse)
# Bil 11: reaktionstid 15 - Chance for forsinkelse (66% chance for forsinkelse)
# Bil 12: reaktionstid 20 - Chance for forsinkelse (33% chance for forsinkelse)
# Bil 13: reaktionstid 30 - Forsinker ikke udrykningskøretøjet (0% chance for forsinkelse)
# Bil 14: reaktionstid 28 - Forsinker ikke udrykningskøretøjet (0% chance for forsinkelse)
# Bil 15: reaktionstid 25 - Chance for forsinkelse (0% chance for forsinkelse)
# Bil 16: reaktionstid 30 - Forsinker ikke udrykningskøretøjet (0% chance for forsinkelse)
# Bil 17: reaktionstid 28 - Forsinker ikke udrykningskøretøjet (0% chance for forsinkelse)
# Bil 18: reaktionstid 17 - Chance for forsinkelse (53% chance for forsinkelse)
# Bil 19: reaktionstid 27 - Forsinker ikke udrykningskøretøjet (0% chance for forsinkelse)
# Bil 20: reaktionstid 18 - Chance for forsinkelse (46% chance for forsinkelse)
# Forsinkelser uden alarm: [46, 33, 100, 33, 73, 86, 66, 100, 66, 33]
# Forsinkelser med alarm: [66, 33, 0, 0, 0, 0, 0, 53, 0, 46]

# %% [markdown]
# #Koden til kort-visualisering

# %%
import json
import folium
import time
from shapely.geometry import LineString, Point
from shapely.ops import transform
import pyproj
from IPython.display import display, clear_output

# Constants
TIME_STEP = 1  # seconds per update
EPSG_UTM = 25832  # UTM Zone for Denmark
EPSG_WGS = 4326   # WGS84

# Function to load GeoJSON LineString from a local file
def load_road_from_geojson(file_path):
    """Loads a LineString from a locally stored GeoJSON file."""
    with open(file_path, 'r') as file:
        geojson_data = json.load(file)

    # Extract coordinates assuming a single LineString
    coordinates = geojson_data['features'][0]['geometry']['coordinates']
    return LineString(coordinates)

# Function to transform coordinates between WGS84 and UTM
def transform_to_utm(line, from_epsg=EPSG_WGS, to_epsg=EPSG_UTM):
    """Transforms a LineString from WGS84 to UTM coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, line)

def transform_to_wgs(point, from_epsg=EPSG_UTM, to_epsg=EPSG_WGS):
    """Transforms a Point from UTM to WGS84 coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, point)

class Car:
    """A simple car simulation moving along a road."""

    def __init__(self, road: LineString, speed_kmh: float):
        """Initializes the car simulation."""
        self.road = road
        self.speed_mps = self.kmh_to_mps(speed_kmh)
        self.position_m = 0  # Start at the beginning of the road
        self.road_length = road.length

    def kmh_to_mps(self, speed_kmh):
        """Converts speed from km/h to m/s."""
        return speed_kmh * 1000 / 3600

    def advance(self, time_step):
        """Advances the car's position based on speed and time step."""
        self.position_m += self.speed_mps * time_step
        self.position_m = min(self.position_m, self.road_length)  # Prevent overshooting

    def get_position(self):
        """Returns the current position of the car as a Shapely Point."""
        return self.road.interpolate(self.position_m)

    def has_reached_end(self):
        """Checks if the car has reached the end of the road."""
        return self.position_m >= self.road_length

# Main simulation function
def simulate_car_movement(geojson_path, speed_kmh):
    """Simulates a car moving along a locally stored road."""

    # Load road and convert to UTM
    road_wgs = load_road_from_geojson(geojson_path)
    road_utm = transform_to_utm(road_wgs)

    # Initialize car
    car = Car(road_utm, speed_kmh)

    # Setup Folium map centered at start point
    start_point_wgs = transform_to_wgs(road_utm.interpolate(0))
    m = folium.Map(location=[start_point_wgs.y, start_point_wgs.x], zoom_start=15)

    # Add road to map
    folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

    # Simulation loop
    while not car.has_reached_end():
        car.advance(TIME_STEP)
        car_pos_wgs = transform_to_wgs(car.get_position())

        # Clear previous markers and add new car icon as a marker
        m = folium.Map(location=[car_pos_wgs.y, car_pos_wgs.x], zoom_start=15)
        folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

        folium.Marker(
            location=[car_pos_wgs.y, car_pos_wgs.x],
            icon=folium.Icon(color="red", icon="car", prefix="fa"),  # Using Font Awesome "car" icon
            popup=f"Speed: {speed_kmh} km/h"
        ).add_to(m)

        # Save map to HTML and reload output
        m.save("car_simulation.html")
        clear_output(wait=True)
        display(m)

        # Print progress
        print(f"Car position: {car.position_m:.2f} meters / {car.road_length:.2f} meters")

        time.sleep(0.5)  # Simulate real-time updates

    print("Car has reached the end of the road.")

# Run simulation with locally saved file
geojson_path = "sample_data/map.geojson"  # Update the path to your map.geojson file
simulate_car_movement(geojson_path, speed_kmh=120)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19999418b145006205ef67ac728cd82d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19999418b145006205ef67ac728cd82d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19999418b145006205ef67ac728cd82d = L.map(
#                 &quot;map_19999418b145006205ef67ac728cd82d&quot;,
#                 {
#                     center: [55.6717760584436, 12.520812301345272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3eafbb32b65e205f30cdf2d176ad607c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3eafbb32b65e205f30cdf2d176ad607c.addTo(map_19999418b145006205ef67ac728cd82d);
#
#
#             var poly_line_25ce5aa79916dc606e13d6dffd6ce3bf = L.polyline(
#                 [[55.683958860947286, 12.572454647354903], [55.68255879795524, 12.570146129687288], [55.681809447875025, 12.569271691176283], [55.68123756578612, 12.568642095448638], [55.67914716700898, 12.565983802376195], [55.67820638145301, 12.564373857887091], [55.677753129215375, 12.56384632359422], [55.67717239211035, 12.563419272023935], [55.676435835087915, 12.563117823856146], [55.67596839747617, 12.563042461813467], [55.674543213946635, 12.564484747699709], [55.67329902903086, 12.56018672472456], [55.67253296057325, 12.557133314169278], [55.67230964790468, 12.555719118663177], [55.67272459386905, 12.55153272322167], [55.672679301409914, 12.54987273540317], [55.67313676468791, 12.54828408633054], [55.674756904112144, 12.532329993518914], [55.67088929489603, 12.531100584375821], [55.67177605844361, 12.520812301345273]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19999418b145006205ef67ac728cd82d);
#
#
#             var marker_b91a8fcca0e47c75a3173adb2d18fe58 = L.marker(
#                 [55.6717760584436, 12.520812301345272],
#                 {
# }
#             ).addTo(map_19999418b145006205ef67ac728cd82d);
#
#
#             var icon_aef9f19036a6c8434264c4b65200b632 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_b91a8fcca0e47c75a3173adb2d18fe58.setIcon(icon_aef9f19036a6c8434264c4b65200b632);
#
#
#         var popup_93e9d23978f36b83442dcba5cdca487f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_015cd628ca42c0601593c74bbf31e16b = $(`&lt;div id=&quot;html_015cd628ca42c0601593c74bbf31e16b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Speed: 120 km/h&lt;/div&gt;`)[0];
#                 popup_93e9d23978f36b83442dcba5cdca487f.setContent(html_015cd628ca42c0601593c74bbf31e16b);
#
#
#
#         marker_b91a8fcca0e47c75a3173adb2d18fe58.bindPopup(popup_93e9d23978f36b83442dcba5cdca487f)
#         ;
#
#
#
#
#             tile_layer_3eafbb32b65e205f30cdf2d176ad607c.addTo(map_19999418b145006205ef67ac728cd82d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# Car position: 4473.60 meters / 4473.60 meters
# Car has reached the end of the road.

# %%
import json
import folium
import time
import random
from shapely.geometry import LineString, Point
from shapely.ops import transform
import pyproj
from IPython.display import display, clear_output

# Constants
TIME_STEP = 1  # seconds per update
EPSG_UTM = 25832  # UTM Zone for Denmark
EPSG_WGS = 4326   # WGS84
ALARM_SPEED_INCREASE = 1.2  # 20% faster for cars with alarms
NO_ALARM_SPEED_DECREASE = 0.8  # 20% slower for cars without alarms
FAST_CAR_SPEED_KMH = 150  # Speed of the faster car in km/h

# Function to load GeoJSON LineString from a local file
def load_road_from_geojson(file_path):
    """Loads a LineString from a locally stored GeoJSON file."""
    with open(file_path, 'r') as file:
        geojson_data = json.load(file)

    # Extract coordinates assuming a single LineString
    coordinates = geojson_data['features'][0]['geometry']['coordinates']
    return LineString(coordinates)

# Function to transform coordinates between WGS84 and UTM
def transform_to_utm(line, from_epsg=EPSG_WGS, to_epsg=EPSG_UTM):
    """Transforms a LineString from WGS84 to UTM coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, line)

def transform_to_wgs(point, from_epsg=EPSG_UTM, to_epsg=EPSG_WGS):
    """Transforms a Point from UTM to WGS84 coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, point)

class Car:
    """A simple car simulation moving along a road."""

    def __init__(self, road: LineString, speed_kmh: float, has_alarm: bool, delay_chance: int):
        """Initializes the car simulation."""
        self.road = road
        self.speed_mps = self.kmh_to_mps(speed_kmh)
        self.position_m = 0  # Start at the beginning of the road
        self.road_length = road.length
        self.has_alarm = has_alarm
        self.delay_chance = delay_chance

        # Apply delay chance: If there's a delay, reduce the speed
        if self.has_alarm:
            self.speed_mps *= ALARM_SPEED_INCREASE  # Increase speed if car has an alarm
        else:
            # Delay effect for cars without alarms
            if random.randint(0, 100) < self.delay_chance:  # Delay happens based on chance
                self.speed_mps *= NO_ALARM_SPEED_DECREASE  # Reduce speed

    def kmh_to_mps(self, speed_kmh):
        """Converts speed from km/h to m/s."""
        return speed_kmh * 1000 / 3600

    def advance(self, time_step):
        """Advances the car's position based on speed and time step."""
        self.position_m += self.speed_mps * time_step
        self.position_m = min(self.position_m, self.road_length)  # Prevent overshooting

    def get_position(self):
        """Returns the current position of the car as a Shapely Point."""
        return self.road.interpolate(self.position_m)

    def has_reached_end(self):
        """Checks if the car has reached the end of the road."""
        return self.position_m >= self.road_length

# Main simulation function
def simulate_car_movement(geojson_path, speed_kmh=120):
    """Simulates multiple cars moving along a locally stored road."""

    # Load road and convert to UTM
    road_wgs = load_road_from_geojson(geojson_path)
    road_utm = transform_to_utm(road_wgs)

    # Create Car A (with alarm) and Car B (without alarm)
    car_a = Car(road_utm, speed_kmh, has_alarm=True, delay_chance=0)  # Car with alarm, no delay
    car_b = Car(road_utm, speed_kmh, has_alarm=False, delay_chance=random.randint(10, 50))  # Car without alarm, possible delay

    # Create Fast Car (Car C)
    fast_car = Car(road_utm, FAST_CAR_SPEED_KMH, has_alarm=False, delay_chance=0)  # Fast car, constant speed

    # Setup Folium map centered at start point
    start_point_wgs = transform_to_wgs(road_utm.interpolate(0))
    m = folium.Map(location=[start_point_wgs.y, start_point_wgs.x], zoom_start=15)

    # Add road to map
    folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

    # Simulation loop
    while not (car_a.has_reached_end() and car_b.has_reached_end()):
        car_a.advance(TIME_STEP)
        car_b.advance(TIME_STEP)
        fast_car.advance(TIME_STEP)

        # Clear previous markers and add new car icons as markers
        m = folium.Map(location=[start_point_wgs.y, start_point_wgs.x], zoom_start=15)
        folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

        # Add car markers
        for car, color in [(car_a, "green"), (car_b, "red"), (fast_car, "blue")]:
            car_pos_wgs = transform_to_wgs(car.get_position())
            folium.Marker(
                location=[car_pos_wgs.y, car_pos_wgs.x],
                icon=folium.Icon(color=color, icon="car", prefix="fa"),  # Car icon
                popup=f"Speed: {speed_kmh} km/h, Alarm: {'Yes' if car.has_alarm else 'No'}"
            ).add_to(m)

        # Save map to HTML and reload output
        m.save("car_simulation.html")
        clear_output(wait=True)
        display(m)

        # Print progress
        print(f"Car A position: {car_a.position_m:.2f} meters / {car_a.road_length:.2f} meters")
        print(f"Car B position: {car_b.position_m:.2f} meters / {car_b.road_length:.2f} meters")
        print(f"Fast Car position: {fast_car.position_m:.2f} meters / {fast_car.road_length:.2f} meters")

        time.sleep(0.5)  # Simulate real-time updates

    print("Both Car A and Car B have reached the end of the road.")

# Run simulation with locally saved file
geojson_path = "sample_data/map.geojson"  # Update the path to your map.geojson file
simulate_car_movement(geojson_path, speed_kmh=120)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_befa74ebaabfeed33fd69d3d1c9cd8bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_befa74ebaabfeed33fd69d3d1c9cd8bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_befa74ebaabfeed33fd69d3d1c9cd8bd = L.map(
#                 &quot;map_befa74ebaabfeed33fd69d3d1c9cd8bd&quot;,
#                 {
#                     center: [55.68395886094729, 12.572454647354903],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ef8ad1e856304091d88745be0c12e39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ef8ad1e856304091d88745be0c12e39.addTo(map_befa74ebaabfeed33fd69d3d1c9cd8bd);
#
#
#             var poly_line_f91a9a8ddf63ba9972fe132dc21a564a = L.polyline(
#                 [[55.683958860947286, 12.572454647354903], [55.68255879795524, 12.570146129687288], [55.681809447875025, 12.569271691176283], [55.68123756578612, 12.568642095448638], [55.67914716700898, 12.565983802376195], [55.67820638145301, 12.564373857887091], [55.677753129215375, 12.56384632359422], [55.67717239211035, 12.563419272023935], [55.676435835087915, 12.563117823856146], [55.67596839747617, 12.563042461813467], [55.674543213946635, 12.564484747699709], [55.67329902903086, 12.56018672472456], [55.67253296057325, 12.557133314169278], [55.67230964790468, 12.555719118663177], [55.67272459386905, 12.55153272322167], [55.672679301409914, 12.54987273540317], [55.67313676468791, 12.54828408633054], [55.674756904112144, 12.532329993518914], [55.67088929489603, 12.531100584375821], [55.67177605844361, 12.520812301345273]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_befa74ebaabfeed33fd69d3d1c9cd8bd);
#
#
#             var marker_9982b22e95ba5d1ce26a0b9051664095 = L.marker(
#                 [55.67603380137857, 12.563053006352263],
#                 {
# }
#             ).addTo(map_befa74ebaabfeed33fd69d3d1c9cd8bd);
#
#
#             var icon_98895cff140d1a6b609a06c14ed05de0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9982b22e95ba5d1ce26a0b9051664095.setIcon(icon_98895cff140d1a6b609a06c14ed05de0);
#
#
#         var popup_df9c1fc544a92c4821f297c31d01b4a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_465c86d5dcf3c7ddcd9ed5795fa1ca76 = $(`&lt;div id=&quot;html_465c86d5dcf3c7ddcd9ed5795fa1ca76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Speed: 120 km/h, Alarm: Yes&lt;/div&gt;`)[0];
#                 popup_df9c1fc544a92c4821f297c31d01b4a6.setContent(html_465c86d5dcf3c7ddcd9ed5795fa1ca76);
#
#
#
#         marker_9982b22e95ba5d1ce26a0b9051664095.bindPopup(popup_df9c1fc544a92c4821f297c31d01b4a6)
#         ;
#
#
#
#
#             var marker_4a54d267bdedcd75f32cdef28415f44d = L.marker(
#                 [55.677594117988434, 12.563729391483717],
#                 {
# }
#             ).addTo(map_befa74ebaabfeed33fd69d3d1c9cd8bd);
#
#
#             var icon_784e8ca45a49c75d6978b0df6d79f8fd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_4a54d267bdedcd75f32cdef28415f44d.setIcon(icon_784e8ca45a49c75d6978b0df6d79f8fd);
#
#
#         var popup_1f54ab9695b1164f390d4b5645bc945b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0cc69276c2807cce603444a46f58f8 = $(`&lt;div id=&quot;html_fc0cc69276c2807cce603444a46f58f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Speed: 120 km/h, Alarm: No&lt;/div&gt;`)[0];
#                 popup_1f54ab9695b1164f390d4b5645bc945b.setContent(html_fc0cc69276c2807cce603444a46f58f8);
#
#
#
#         marker_4a54d267bdedcd75f32cdef28415f44d.bindPopup(popup_1f54ab9695b1164f390d4b5645bc945b)
#         ;
#
#
#
#
#             var marker_a9cdd1a2a5aeb0c353c857c1e6abcc87 =
# Car A position: 1080.00 meters / 4473.60 meters
# Car B position: 900.00 meters / 4473.60 meters
# Fast Car position: 1125.00 meters / 4473.60 meters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-804579c19047> in <cell line: 0>()
#     131 # Run simulation with locally saved file
#     132 geojson_path = "sample_data/map.geojson"  # Update the path to your map.geojson file
# --> 133 simulate_car_movement(geojson_path, speed_kmh=120)
#
# <ipython-input-21-804579c19047> in simulate_car_movement(geojson_path, speed_kmh)
#     125         print(f"Fast Car position: {fast_car.position_m:.2f} meters / {fast_car.road_length:.2f} meters")
#     126
# --> 127         time.sleep(0.5)  # Simulate real-time updates
#     128
#     129     print("Both Car A and Car B have reached the end of the road.")
#
# KeyboardInterrupt:

# %%
import json
import folium
import time
import random
from shapely.geometry import LineString, Point
from shapely.ops import transform
import pyproj
from IPython.display import display, clear_output

# Constants
TIME_STEP = 1  # seconds per update
EPSG_UTM = 25832  # UTM Zone for Denmark
EPSG_WGS = 4326   # WGS84
ALARM_SPEED_INCREASE = 1.2  # 20% faster for cars with alarms
NO_ALARM_SPEED_DECREASE = 0.8  # 20% slower for cars without alarms
FAST_CAR_SPEED_KMH = 150  # Speed of the faster car in km/h

# Function to load GeoJSON LineString from a local file
def load_road_from_geojson(file_path):
    """Loads a LineString from a locally stored GeoJSON file."""
    with open(file_path, 'r') as file:
        geojson_data = json.load(file)

    # Extract coordinates assuming a single LineString
    coordinates = geojson_data['features'][0]['geometry']['coordinates']
    return LineString(coordinates)

# Function to transform coordinates between WGS84 and UTM
def transform_to_utm(line, from_epsg=EPSG_WGS, to_epsg=EPSG_UTM):
    """Transforms a LineString from WGS84 to UTM coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, line)

def transform_to_wgs(point, from_epsg=EPSG_UTM, to_epsg=EPSG_WGS):
    """Transforms a Point from UTM to WGS84 coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, point)

class Car:
    """A simple car simulation moving along a road."""

    def __init__(self, road: LineString, speed_kmh: float, has_alarm: bool, delay_chance: int):
        """Initializes the car simulation."""
        self.road = road
        self.speed_mps = self.kmh_to_mps(speed_kmh)
        self.position_m = 0  # Start at the beginning of the road
        self.road_length = road.length
        self.has_alarm = has_alarm
        self.delay_chance = delay_chance

        # Apply delay chance: If there's a delay, reduce the speed
        if self.has_alarm:
            self.speed_mps *= ALARM_SPEED_INCREASE  # Increase speed if car has an alarm
        else:
            # Delay effect for cars without alarms
            if random.randint(0, 100) < self.delay_chance:  # Delay happens based on chance
                self.speed_mps *= NO_ALARM_SPEED_DECREASE  # Reduce speed

    def kmh_to_mps(self, speed_kmh):
        """Converts speed from km/h to m/s."""
        return speed_kmh * 1000 / 3600

    def advance(self, time_step):
        """Advances the car's position based on speed and time step."""
        self.position_m += self.speed_mps * time_step
        self.position_m = min(self.position_m, self.road_length)  # Prevent overshooting

    def get_position(self):
        """Returns the current position of the car as a Shapely Point."""
        return self.road.interpolate(self.position_m)

    def has_reached_end(self):
        """Checks if the car has reached the end of the road."""
        return self.position_m >= self.road_length

# Main simulation function
def simulate_car_movement(geojson_path, speed_kmh=120):
    """Simulates multiple cars moving along a locally stored road."""

    # Load road and convert to UTM
    road_wgs = load_road_from_geojson(geojson_path)
    road_utm = transform_to_utm(road_wgs)

    # Create Car A (with alarm) and Car B (without alarm)
    car_a = Car(road_utm, speed_kmh, has_alarm=True, delay_chance=0)  # Car with alarm, no delay
    car_b = Car(road_utm, speed_kmh, has_alarm=False, delay_chance=random.randint(10, 50))  # Car without alarm, possible delay

    # Create Fast Car (Car C)
    fast_car = Car(road_utm, FAST_CAR_SPEED_KMH, has_alarm=False, delay_chance=0)  # Fast car, constant speed

    # Setup Folium map centered at start point
    start_point_wgs = transform_to_wgs(road_utm.interpolate(0))
    m = folium.Map(location=[start_point_wgs.y, start_point_wgs.x], zoom_start=15)

    # Add road to map
    folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

    # Simulation loop
    while not (car_a.has_reached_end() and car_b.has_reached_end()):
        car_a.advance(TIME_STEP)
        car_b.advance(TIME_STEP)
        fast_car.advance(TIME_STEP)

        # Clear previous markers and add new car icons as markers
        m = folium.Map(location=[start_point_wgs.y, start_point_wgs.x], zoom_start=15, control_scale=True)
        folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

        # Add car markers (using FontAwesome icons for car and police)
        for car, color, icon in [(car_a, "green", "car"), (car_b, "red", "car"), (fast_car, "blue", "police")]:
            car_pos_wgs = transform_to_wgs(car.get_position())
            folium.Marker(
                location=[car_pos_wgs.y, car_pos_wgs.x],
                icon=folium.Icon(color=color, icon=icon, prefix="fa"),  # Use FontAwesome car and police icons
                popup=f"Speed: {speed_kmh} km/h, Alarm: {'Yes' if car.has_alarm else 'No'}"
            ).add_to(m)

        # Dynamically adjust the zoom level and map center based on car positions
        car_positions = [transform_to_wgs(car.get_position()) for car in [car_a, car_b, fast_car]]
        latitudes = [pos.y for pos in car_positions]
        longitudes = [pos.x for pos in car_positions]
        avg_lat = sum(latitudes) / len(latitudes)
        avg_lon = sum(longitudes) / len(longitudes)
        max_distance = max([car_a.position_m, car_b.position_m, fast_car.position_m])
        zoom_level = 15 if max_distance < road_utm.length * 0.5 else 14  # Adjust zoom based on distance

        m.location = [avg_lat, avg_lon]  # Center map at average position of all cars
        m.zoom_start = zoom_level  # Adjust zoom

        # Save map to HTML and reload output
        m.save("car_simulation.html")
        clear_output(wait=True)
        display(m)

        # Print progress
        print(f"Car A position: {car_a.position_m:.2f} meters / {car_a.road_length:.2f} meters")
        print(f"Car B position: {car_b.position_m:.2f} meters / {car_b.road_length:.2f} meters")
        print(f"Fast Car position: {fast_car.position_m:.2f} meters / {fast_car.road_length:.2f} meters")

        time.sleep(0.5)  # Simulate real-time updates

    print("Both Car A and Car B have reached the end of the road.")

# Run simulation with locally saved file
geojson_path = "sample_data/map.geojson"  # Update the path to your map.geojson file
simulate_car_movement(geojson_path, speed_kmh=120)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3db77b3deb12b034b2d78a4e6d730d2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3db77b3deb12b034b2d78a4e6d730d2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3db77b3deb12b034b2d78a4e6d730d2c = L.map(
#                 &quot;map_3db77b3deb12b034b2d78a4e6d730d2c&quot;,
#                 {
#                     center: [55.673052477167225, 12.559087975672291],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3db77b3deb12b034b2d78a4e6d730d2c);
#
#
#
#
#
#             var tile_layer_b2c0b35168fa877a676170b665c1de0d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2c0b35168fa877a676170b665c1de0d.addTo(map_3db77b3deb12b034b2d78a4e6d730d2c);
#
#
#             var poly_line_761c65efeebfe4c1f784605143cc2f22 = L.polyline(
#                 [[55.683958860947286, 12.572454647354903], [55.68255879795524, 12.570146129687288], [55.681809447875025, 12.569271691176283], [55.68123756578612, 12.568642095448638], [55.67914716700898, 12.565983802376195], [55.67820638145301, 12.564373857887091], [55.677753129215375, 12.56384632359422], [55.67717239211035, 12.563419272023935], [55.676435835087915, 12.563117823856146], [55.67596839747617, 12.563042461813467], [55.674543213946635, 12.564484747699709], [55.67329902903086, 12.56018672472456], [55.67253296057325, 12.557133314169278], [55.67230964790468, 12.555719118663177], [55.67272459386905, 12.55153272322167], [55.672679301409914, 12.54987273540317], [55.67313676468791, 12.54828408633054], [55.674756904112144, 12.532329993518914], [55.67088929489603, 12.531100584375821], [55.67177605844361, 12.520812301345273]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3db77b3deb12b034b2d78a4e6d730d2c);
#
#
#             var marker_e4454abe6f67738736b1f07dc89420d0 = L.marker(
#                 [55.67276720014722, 12.558066905531378],
#                 {
# }
#             ).addTo(map_3db77b3deb12b034b2d78a4e6d730d2c);
#
#
#             var icon_3727786fb44770c6ae4bbf2284a12364 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_e4454abe6f67738736b1f07dc89420d0.setIcon(icon_3727786fb44770c6ae4bbf2284a12364);
#
#
#         var popup_f4f97a4c3c5839771008963d9b01b923 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6574244cc6a508dd87425ab5d96d6919 = $(`&lt;div id=&quot;html_6574244cc6a508dd87425ab5d96d6919&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Speed: 120 km/h, Alarm: Yes&lt;/div&gt;`)[0];
#                 popup_f4f97a4c3c5839771008963d9b01b923.setContent(html_6574244cc6a508dd87425ab5d96d6919);
#
#
#
#         marker_e4454abe6f67738736b1f07dc89420d0.bindPopup(popup_f4f97a4c3c5839771008963d9b01b923)
#         ;
#
#
#
#
#             var marker_fa9ff4f29b38ba519d29bf3e095afc42 = L.marker(
#                 [55.67387511217904, 12.562176697821759],
#                 {
# }
#             ).addTo(map_3db77b3deb12b034b2d78a4e6d730d2c);
#
#
#             var icon_1a373bcc44137c41e2d5f207bd02d56c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_fa9ff4f29b38ba519d29bf3e095afc42.setIcon(icon_1a373bcc44137c41e2d5f207bd02d56c);
#
#
#         var popup_37913b61c0855c76b52a89689bb8f6a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b2d12a63ecb6b412ed29c7de0f8f82a = $(`&lt;div id=&quot;html_7b2d12a63ecb6b412ed29c7de0f8f82a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Speed: 120 km/h, Alarm: No&lt;/div&gt;`)[0];
#                 popup_37913b61c0855c76b52a89689bb8f6a5.setContent(html_7b2d12a63ecb6b412ed29c7de0f8f82a);
#
#
#
#         marker_fa9ff4f29b38ba519d29bf3e095afc42.bindPopup(popup_37913b61c0855c76b52a89689bb8f6a5)
#         ;
# Car A position: 1720.00 meters / 4473.60 meters
# Car B position: 1433.33 meters / 4473.60 meters
# Fast Car position: 1791.67 meters / 4473.60 meters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-6c5154680020> in <cell line: 0>()
#     143 # Run simulation with locally saved file
#     144 geojson_path = "sample_data/map.geojson"  # Update the path to your map.geojson file
# --> 145 simulate_car_movement(geojson_path, speed_kmh=120)
#
# <ipython-input-22-6c5154680020> in simulate_car_movement(geojson_path, speed_kmh)
#     137         print(f"Fast Car position: {fast_car.position_m:.2f} meters / {fast_car.road_length:.2f} meters")
#     138
# --> 139         time.sleep(0.5)  # Simulate real-time updates
#     140
#     141     print("Both Car A and Car B have reached the end of the road.")
#
# KeyboardInterrupt:

# %%
import json
import folium
import time
import random
from shapely.geometry import LineString, Point
from shapely.ops import transform
import pyproj
from IPython.display import display, clear_output

# Constants
TIME_STEP = 1  # seconds per update
EPSG_UTM = 25832  # UTM Zone for Denmark
EPSG_WGS = 4326   # WGS84
ALARM_SPEED_INCREASE = 1.2  # 20% faster for cars with alarms
NO_ALARM_SPEED_DECREASE = 0.8  # 20% slower for cars without alarms
FAST_CAR_SPEED_KMH = 150  # Speed of the faster car in km/h

# Function to load GeoJSON LineString from a local file
def load_road_from_geojson(file_path):
    """Loads a LineString from a locally stored GeoJSON file."""
    with open(file_path, 'r') as file:
        geojson_data = json.load(file)

    # Extract coordinates assuming a single LineString
    coordinates = geojson_data['features'][0]['geometry']['coordinates']
    return LineString(coordinates)

# Function to transform coordinates between WGS84 and UTM
def transform_to_utm(line, from_epsg=EPSG_WGS, to_epsg=EPSG_UTM):
    """Transforms a LineString from WGS84 to UTM coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, line)

def transform_to_wgs(point, from_epsg=EPSG_UTM, to_epsg=EPSG_WGS):
    """Transforms a Point from UTM to WGS84 coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, point)

class Car:
    """A simple car simulation moving along a road."""

    def __init__(self, road: LineString, speed_kmh: float, has_alarm: bool, delay_chance: int, start_delay: float = 0):
        """Initializes the car simulation."""
        self.road = road
        self.speed_mps = self.kmh_to_mps(speed_kmh)
        self.position_m = 0  # Start at the beginning of the road
        self.road_length = road.length
        self.has_alarm = has_alarm
        self.delay_chance = delay_chance
        self.start_delay = start_delay  # Delay for the fastest car to start

        # Apply delay chance: If there's a delay, reduce the speed
        if self.has_alarm:
            self.speed_mps *= ALARM_SPEED_INCREASE  # Increase speed if car has an alarm
        else:
            # Delay effect for cars without alarms
            if random.randint(0, 100) < self.delay_chance:  # Delay happens based on chance
                self.speed_mps *= NO_ALARM_SPEED_DECREASE  # Reduce speed

    def kmh_to_mps(self, speed_kmh):
        """Converts speed from km/h to m/s."""
        return speed_kmh * 1000 / 3600

    def advance(self, time_step):
        """Advances the car's position based on speed and time step."""
        self.position_m += self.speed_mps * time_step
        self.position_m = min(self.position_m, self.road_length)  # Prevent overshooting

    def get_position(self):
        """Returns the current position of the car as a Shapely Point."""
        return self.road.interpolate(self.position_m)

    def has_reached_end(self):
        """Checks if the car has reached the end of the road."""
        return self.position_m >= self.road_length

# Main simulation function
def simulate_car_movement(geojson_path, speed_kmh=120):
    """Simulates multiple cars moving along a locally stored road."""

    # Load road and convert to UTM
    road_wgs = load_road_from_geojson(geojson_path)
    road_utm = transform_to_utm(road_wgs)

    # Create Car A (with alarm) and Car B (without alarm)
    car_a = Car(road_utm, speed_kmh, has_alarm=True, delay_chance=0)  # Car with alarm, no delay
    car_b = Car(road_utm, speed_kmh, has_alarm=False, delay_chance=random.randint(10, 50))  # Car without alarm, possible delay

    # Create Fast Car (Car C) with delayed start
    fast_car = Car(road_utm, FAST_CAR_SPEED_KMH, has_alarm=False, delay_chance=0, start_delay=5)  # Fast car, starts later

    # Setup Folium map centered at start point
    start_point_wgs = transform_to_wgs(road_utm.interpolate(0))
    m = folium.Map(location=[start_point_wgs.y, start_point_wgs.x], zoom_start=15)

    # Add road to map
    folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

    # Simulation loop
    time_elapsed = 0  # Track the overall time to simulate start delay for the fastest car
    while not (car_a.has_reached_end() and car_b.has_reached_end()):
        # Introduce delay for the fast car to start
        if time_elapsed >= fast_car.start_delay:
            fast_car.advance(TIME_STEP)

        car_a.advance(TIME_STEP)
        car_b.advance(TIME_STEP)

        # Clear previous markers and add new car icons as markers
        m = folium.Map(location=[start_point_wgs.y, start_point_wgs.x], zoom_start=15, control_scale=True)
        folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

        # Add car markers (using FontAwesome icons for car and police)
        for car, color, icon in [(car_a, "green", "car"), (car_b, "red", "car"), (fast_car, "blue", "police")]:
            car_pos_wgs = transform_to_wgs(car.get_position())
            folium.Marker(
                location=[car_pos_wgs.y, car_pos_wgs.x],
                icon=folium.Icon(color=color, icon=icon, prefix="fa"),  # Use FontAwesome car and police icons
                popup=f"Speed: {speed_kmh} km/h, Alarm: {'Yes' if car.has_alarm else 'No'}"
            ).add_to(m)

        # Dynamically adjust the zoom level and map center based on car positions
        car_positions = [transform_to_wgs(car.get_position()) for car in [car_a, car_b, fast_car]]
        latitudes = [pos.y for pos in car_positions]
        longitudes = [pos.x for pos in car_positions]
        avg_lat = sum(latitudes) / len(latitudes)
        avg_lon = sum(longitudes) / len(longitudes)
        max_distance = max([car_a.position_m, car_b.position_m, fast_car.position_m])
        zoom_level = 15 if max_distance < road_utm.length * 0.5 else 14  # Adjust zoom based on distance

        m.location = [avg_lat, avg_lon]  # Center map at average position of all cars
        m.zoom_start = zoom_level  # Adjust zoom

        # Save map to HTML and reload output
        m.save("car_simulation.html")
        clear_output(wait=True)
        display(m)

        # Print progress
        print(f"Car A position: {car_a.position_m:.2f} meters / {car_a.road_length:.2f} meters")
        print(f"Car B position: {car_b.position_m:.2f} meters / {car_b.road_length:.2f} meters")
        print(f"Fast Car position: {fast_car.position_m:.2f} meters / {fast_car.road_length:.2f} meters")

        time_elapsed += TIME_STEP  # Increment the total time
        time.sleep(0.5)  # Simulate real-time updates

    print("All cars have reached the end of the road.")

# Run simulation with locally saved file
geojson_path = "sample_data/map.geojson"  # Update the path to your map.geojson file
simulate_car_movement(geojson_path, speed_kmh=120)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01561cd14297eb17da072d0357a17783 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01561cd14297eb17da072d0357a17783&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01561cd14297eb17da072d0357a17783 = L.map(
#                 &quot;map_01561cd14297eb17da072d0357a17783&quot;,
#                 {
#                     center: [55.671776058443605, 12.520812301345272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_01561cd14297eb17da072d0357a17783);
#
#
#
#
#
#             var tile_layer_6b12edb3dd9262ee52f1e69ebdd74416 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b12edb3dd9262ee52f1e69ebdd74416.addTo(map_01561cd14297eb17da072d0357a17783);
#
#
#             var poly_line_5f06d066b4eae6d2ca05acbd80066080 = L.polyline(
#                 [[55.683958860947286, 12.572454647354903], [55.68255879795524, 12.570146129687288], [55.681809447875025, 12.569271691176283], [55.68123756578612, 12.568642095448638], [55.67914716700898, 12.565983802376195], [55.67820638145301, 12.564373857887091], [55.677753129215375, 12.56384632359422], [55.67717239211035, 12.563419272023935], [55.676435835087915, 12.563117823856146], [55.67596839747617, 12.563042461813467], [55.674543213946635, 12.564484747699709], [55.67329902903086, 12.56018672472456], [55.67253296057325, 12.557133314169278], [55.67230964790468, 12.555719118663177], [55.67272459386905, 12.55153272322167], [55.672679301409914, 12.54987273540317], [55.67313676468791, 12.54828408633054], [55.674756904112144, 12.532329993518914], [55.67088929489603, 12.531100584375821], [55.67177605844361, 12.520812301345273]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_01561cd14297eb17da072d0357a17783);
#
#
#             var marker_19d9aa9253fa0803eff1fd00b21796cd = L.marker(
#                 [55.6717760584436, 12.520812301345272],
#                 {
# }
#             ).addTo(map_01561cd14297eb17da072d0357a17783);
#
#
#             var icon_e5027b600acbb8d3a28bc910bff6c41d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_19d9aa9253fa0803eff1fd00b21796cd.setIcon(icon_e5027b600acbb8d3a28bc910bff6c41d);
#
#
#         var popup_e5815e7ac4d1890606f2a9f7c5a0cead = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cb1d6435d1d25b8d69435226656a0a5 = $(`&lt;div id=&quot;html_0cb1d6435d1d25b8d69435226656a0a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Speed: 120 km/h, Alarm: Yes&lt;/div&gt;`)[0];
#                 popup_e5815e7ac4d1890606f2a9f7c5a0cead.setContent(html_0cb1d6435d1d25b8d69435226656a0a5);
#
#
#
#         marker_19d9aa9253fa0803eff1fd00b21796cd.bindPopup(popup_e5815e7ac4d1890606f2a9f7c5a0cead)
#         ;
#
#
#
#
#             var marker_3593d4eedf0f8c1fed12091976aeaeff = L.marker(
#                 [55.6717760584436, 12.520812301345272],
#                 {
# }
#             ).addTo(map_01561cd14297eb17da072d0357a17783);
#
#
#             var icon_a7aa70e6f4e74d81f050b103a6ce0c6d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3593d4eedf0f8c1fed12091976aeaeff.setIcon(icon_a7aa70e6f4e74d81f050b103a6ce0c6d);
#
#
#         var popup_f17f5c1bc52dc364cd6d0b8da8df99af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77f6e044dee9eacd0c2905a36bbfa8a8 = $(`&lt;div id=&quot;html_77f6e044dee9eacd0c2905a36bbfa8a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Speed: 120 km/h, Alarm: No&lt;/div&gt;`)[0];
#                 popup_f17f5c1bc52dc364cd6d0b8da8df99af.setContent(html_77f6e044dee9eacd0c2905a36bbfa8a8);
#
#
#
#         marker_3593d4eedf0f8c1fed12091976aeaeff.bindPopup(popup_f17f5c1bc52dc364cd6d0b8da8df99af)
#         ;
# Car A position: 4473.60 meters / 4473.60 meters
# Car B position: 4473.60 meters / 4473.60 meters
# Fast Car position: 4473.60 meters / 4473.60 meters
# All cars have reached the end of the road.

# %%
import json
import folium
import time
import random
from shapely.geometry import LineString, Point
from shapely.ops import transform
import pyproj
from IPython.display import display, clear_output

# Constants
TIME_STEP = 1  # seconds per update
EPSG_UTM = 25832  # UTM Zone for Denmark
EPSG_WGS = 4326   # WGS84
ALARM_SPEED_INCREASE = 1.2  # 20% faster for cars with alarms
NO_ALARM_SPEED_DECREASE = 0.8  # 20% slower for cars without alarms
FAST_CAR_SPEED_KMH = 180  # Speed of the police car in km/h (faster than the others)

# Function to load GeoJSON LineString from a local file
def load_road_from_geojson(file_path):
    """Loads a LineString from a locally stored GeoJSON file."""
    with open(file_path, 'r') as file:
        geojson_data = json.load(file)

    # Extract coordinates assuming a single LineString
    coordinates = geojson_data['features'][0]['geometry']['coordinates']
    return LineString(coordinates)

# Function to transform coordinates between WGS84 and UTM
def transform_to_utm(line, from_epsg=EPSG_WGS, to_epsg=EPSG_UTM):
    """Transforms a LineString from WGS84 to UTM coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, line)

def transform_to_wgs(point, from_epsg=EPSG_UTM, to_epsg=EPSG_WGS):
    """Transforms a Point from UTM to WGS84 coordinates."""
    transformer = pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform
    return transform(transformer, point)

class Car:
    """A simple car simulation moving along a road."""

    def __init__(self, road: LineString, speed_kmh: float, has_alarm: bool, delay_chance: int, start_delay: float = 0):
        """Initializes the car simulation."""
        self.road = road
        self.speed_mps = self.kmh_to_mps(speed_kmh)
        self.position_m = 0  # Start at the beginning of the road
        self.road_length = road.length
        self.has_alarm = has_alarm
        self.delay_chance = delay_chance
        self.start_delay = start_delay  # Delay for the fastest car to start

        # Apply delay chance: If there's a delay, reduce the speed
        if self.has_alarm:
            self.speed_mps *= ALARM_SPEED_INCREASE  # Increase speed if car has an alarm
        else:
            # Delay effect for cars without alarms
            if random.randint(0, 100) < self.delay_chance:  # Delay happens based on chance
                self.speed_mps *= NO_ALARM_SPEED_DECREASE  # Reduce speed

    def kmh_to_mps(self, speed_kmh):
        """Converts speed from km/h to m/s."""
        return speed_kmh * 1000 / 3600

    def advance(self, time_step):
        """Advances the car's position based on speed and time step."""
        self.position_m += self.speed_mps * time_step
        self.position_m = min(self.position_m, self.road_length)  # Prevent overshooting

    def get_position(self):
        """Returns the current position of the car as a Shapely Point."""
        return self.road.interpolate(self.position_m)

    def has_reached_end(self):
        """Checks if the car has reached the end of the road."""
        return self.position_m >= self.road_length

# Main simulation function
def simulate_car_movement(geojson_path, speed_kmh=120):
    """Simulates multiple cars moving along a locally stored road."""

    # Load road and convert to UTM
    road_wgs = load_road_from_geojson(geojson_path)
    road_utm = transform_to_utm(road_wgs)

    # Create Car A (with alarm) and Car B (without alarm)
    car_a = Car(road_utm, speed_kmh, has_alarm=True, delay_chance=0)  # Car with alarm, no delay
    car_b = Car(road_utm, speed_kmh, has_alarm=False, delay_chance=random.randint(10, 50))  # Car without alarm, possible delay

    # Create Fast Car (Car C) with delayed start (faster)
    fast_car = Car(road_utm, FAST_CAR_SPEED_KMH, has_alarm=False, delay_chance=0, start_delay=5)  # Fast car, starts later

    # Setup Folium map centered at start point
    start_point_wgs = transform_to_wgs(road_utm.interpolate(0))
    m = folium.Map(location=[start_point_wgs.y, start_point_wgs.x], zoom_start=15)

    # Add road to map
    folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

    # Custom car icons (file paths for local images)
    red_car_icon = folium.CustomIcon(icon_image='sample_data/redcar.png', icon_size=(40, 40))  # Red car image
    blue_car_icon = folium.CustomIcon(icon_image='sample_data/bluecar.png', icon_size=(40, 40))  # Blue car image
    police_car_icon = folium.CustomIcon(icon_image='sample_data/policecar.png', icon_size=(50, 50))  # Police car image

    # Simulation loop
    time_elapsed = 0  # Track the overall time to simulate start delay for the fastest car
    while not (car_a.has_reached_end() and car_b.has_reached_end()):
        # Introduce delay for the fast car to start
        if time_elapsed >= fast_car.start_delay:
            fast_car.advance(TIME_STEP)

        car_a.advance(TIME_STEP)
        car_b.advance(TIME_STEP)

        # Clear previous markers and add new car icons as markers
        m = folium.Map(location=[start_point_wgs.y, start_point_wgs.x], zoom_start=15, control_scale=True)
        folium.PolyLine([(pt[1], pt[0]) for pt in road_wgs.coords], color="blue", weight=3).add_to(m)

        # Add car markers (using custom images for each car)
        for car, icon in [(car_a, red_car_icon), (car_b, blue_car_icon), (fast_car, police_car_icon)]:
            car_pos_wgs = transform_to_wgs(car.get_position())
            folium.Marker(
                location=[car_pos_wgs.y, car_pos_wgs.x],
                icon=icon,
                popup=f"Speed: {speed_kmh} km/h, Alarm: {'Yes' if car.has_alarm else 'No'}"
            ).add_to(m)

        # Dynamically adjust the zoom level and map center based on car positions
        car_positions = [transform_to_wgs(car.get_position()) for car in [car_a, car_b, fast_car]]
        latitudes = [pos.y for pos in car_positions]
        longitudes = [pos.x for pos in car_positions]
        avg_lat = sum(latitudes) / len(latitudes)
        avg_lon = sum(longitudes) / len(longitudes)
        max_distance = max([car_a.position_m, car_b.position_m, fast_car.position_m])
        zoom_level = 15 if max_distance < road_utm.length * 0.5 else 14  # Adjust zoom based on distance

        m.location = [avg_lat, avg_lon]  # Center map at average position of all cars
        m.zoom_start = zoom_level  # Adjust zoom

        # Save map to HTML and reload output
        m.save("car_simulation.html")
        clear_output(wait=True)
        display(m)

        # Print progress
        print(f"Car A position: {car_a.position_m:.2f} meters / {car_a.road_length:.2f} meters")
        print(f"Car B position: {car_b.position_m:.2f} meters / {car_b.road_length:.2f} meters")
        print(f"Fast Car position: {fast_car.position_m:.2f} meters / {fast_car.road_length:.2f} meters")

        time_elapsed += TIME_STEP  # Increment the total time
        time.sleep(0.5)  # Simulate real-time updates

    print("All cars have reached the end of the road.")

# Run simulation with locally saved file
geojson_path = "sample_data/map.geojson"  # Update the path to your map.geojson file
simulate_car_movement(geojson_path, speed_kmh=120)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c8a697488c85> in <cell line: 0>()
#     154 # Run simulation with locally saved file
#     155 geojson_path = "sample_data/map.geojson"  # Update the path to your map.geojson file
# --> 156 simulate_car_movement(geojson_path, speed_kmh=120)
#
# <ipython-input-2-c8a697488c85> in simulate_car_movement(geojson_path, speed_kmh)
#      80
#      81     # Load road and convert to UTM
# ---> 82     road_wgs = load_road_from_geojson(geojson_path)
#      83     road_utm = transform_to_utm(road_wgs)
#      84
#
# <ipython-input-2-c8a697488c85> in load_road_from_geojson(file_path)
#      19 def load_road_from_geojson(file_path):
#      20     """Loads a LineString from a locally stored GeoJSON file."""
# ---> 21     with open(file_path, 'r') as file:
#      22         geojson_data = json.load(file)
#      23
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_data/map.geojson'

# %%
import json
import folium
import time
import random
from shapely.geometry import LineString
from shapely.ops import transform
import pyproj
from IPython.display import display, clear_output

# Constants
TIME_STEP = 0.5  # Reduced time per update for faster simulation
ALARM_SPEED_MULTIPLIER = 1.2
NO_ALARM_SPEED_MULTIPLIER = 0.8
FAST_CAR_SPEED_KMH = 180
FAST_CAR_DELAY = 3  # Fast car starts slightly sooner

# Load road from GeoJSON
def load_road(file_path):
    with open(file_path, 'r') as file:
        return LineString(json.load(file)['features'][0]['geometry']['coordinates'])

# Transform coordinates
def transform_coords(geom, from_epsg=4326, to_epsg=25832):
    return transform(pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform, geom)

# Car class
class Car:
    def __init__(self, road, speed_kmh, has_alarm=False, delay_chance=0, start_delay=0):
        self.road = transform_coords(road)
        self.speed_mps = (speed_kmh * 1000 / 3600) * (ALARM_SPEED_MULTIPLIER if has_alarm else NO_ALARM_SPEED_MULTIPLIER if random.randint(0, 100) < delay_chance else 1)
        self.position_m = 0
        self.start_delay = start_delay

    def advance(self):
        self.position_m = min(self.position_m + self.speed_mps * TIME_STEP, self.road.length)

    def get_position(self):
        return transform_coords(self.road.interpolate(self.position_m), from_epsg=25832, to_epsg=4326)

# Simulation
def run_simulation(geojson_path, speed_kmh=120):
    road = load_road(geojson_path)

    car_a = Car(road, speed_kmh, has_alarm=True)
    car_b = Car(road, speed_kmh, delay_chance=random.randint(10, 50))
    fast_car = Car(road, FAST_CAR_SPEED_KMH, start_delay=FAST_CAR_DELAY)

    icons = {
        car_a: folium.CustomIcon("sample_data/redcar.png", icon_size=(40, 40)),
        car_b: folium.CustomIcon("sample_data/bluecar.png", icon_size=(40, 40)),
        fast_car: folium.CustomIcon("sample_data/policecar.png", icon_size=(50, 50)),
    }

    time_elapsed = 0
    while car_a.position_m < car_a.road.length or car_b.position_m < car_b.road.length:
        if time_elapsed >= fast_car.start_delay:
            fast_car.advance()
        car_a.advance()
        car_b.advance()

        map_center = car_a.get_position()
        m = folium.Map(location=[map_center.y, map_center.x], zoom_start=15, control_scale=True)
        folium.PolyLine([(pt[1], pt[0]) for pt in road.coords], color="blue", weight=3).add_to(m)

        for car in [car_a, car_b, fast_car]:
            folium.Marker(
                location=[car.get_position().y, car.get_position().x], icon=icons[car]
            ).add_to(m)

        m.save("car_simulation.html")
        clear_output(wait=True)
        display(m)

        time_elapsed += TIME_STEP
        time.sleep(0.25)  # Faster updates

    print("Simulation complete.")

# Run the simulation
run_simulation("sample_data/map.geojson", speed_kmh=120)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-cfe4cd3d53dd> in <cell line: 0>()
#      78
#      79 # Run the simulation
# ---> 80 run_simulation("sample_data/map.geojson", speed_kmh=120)
#
# <ipython-input-8-cfe4cd3d53dd> in run_simulation(geojson_path, speed_kmh)
#      70         m.save("car_simulation.html")
#      71         clear_output(wait=True)
# ---> 72         display(m)
#      73
#      74         time_elapsed += TIME_STEP
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.11/dist-packages/folium/folium.py in _repr_html_(self, **kwargs)
#     333             self._parent = None
#     334         else:
# --> 335             out = self._parent._repr_html_(**kwargs)
#     336         return out
#     337
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in _repr_html_(self, **kwargs)
#     408     def _repr_html_(self, **kwargs) -> str:
#     409         """Displays the Figure in a Jupyter notebook."""
# --> 410         html = escape(self.render(**kwargs))
#     411         if self.height is None:
#     412             iframe = (
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in render(self, **kwargs)
#     403         """Renders the HTML representation of the element."""
#     404         for name, child in self._children.items():
# --> 405             child.render(**kwargs)
#     406         return self._template.render(this=self, kwargs=kwargs)
#     407
#
# /usr/local/lib/python3.11/dist-packages/folium/folium.py in render(self, **kwargs)
#     415         )
#     416
# --> 417         super().render(**kwargs)
#     418
#     419     def show_in_browser(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/folium/elements.py in render(self, **kwargs)
#      25             figure.header.add_child(CssLink(url), name=name)
#      26
# ---> 27         super().render(**kwargs)
#      28
#      29     def add_css_link(self, name: str, url: str):
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in render(self, **kwargs)
#     734
#     735         for name, element in self._children.items():
# --> 736             element.render(**kwargs)
#
# /usr/local/lib/python3.11/dist-packages/folium/map.py in render(self)
#     411                 f"{self._name} location must be assigned when added directly to map."
#     412             )
# --> 413         super().render()
#     414
#     415
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in render(self, **kwargs)
#     734
#     735         for name, element in self._children.items():
# --> 736             element.render(**kwargs)
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in render(self, **kwargs)
#     731         script = self._template.module.__dict__.get("script", None)
#     732         if script is not None:
# --> 733             figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     734
#     735         for name, element in self._children.items():
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in __init__(self, template, template_name)
#      66
#      67         if template is not None:
# ---> 68             self._template = Template(template)
#      69         elif template_name is not None:
#      70             self._template = ENV.get_template(template_name)
#
# /usr/local/lib/python3.11/dist-packages/jinja2/environment.py in __new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape, enable_async)
#    1212             enable_async,
#    1213         )
# -> 1214         return env.from_string(source, template_class=cls)
#    1215
#    1216     @classmethod
#
# /usr/local/lib/python3.11/dist-packages/jinja2/environment.py in from_string(self, source, globals, template_class)
#    1109         gs = self.make_globals(globals)
#    1110         cls = template_class or self.template_class
# -> 1111         return cls.from_code(self, self.compile(source), gs, None)
#    1112
#    1113     def make_globals(
#
# /usr/local/lib/python3.11/dist-packages/jinja2/environment.py in compile(self, source, name, filename, raw, defer_init)
#     762                 source_hint = source
#     763                 source = self._parse(source, name, filename)
# --> 764             source = self._generate(source, name, filename, defer_init=defer_init)
#     765             if raw:
#     766                 return source
#
# /usr/local/lib/python3.11/dist-packages/jinja2/environment.py in _generate(self, source, name, filename, defer_init)
#     692         .. versionadded:: 2.5
#     693         """
# --> 694         return generate(  # type: ignore
#     695             source,
#     696             self,
#
# /usr/local/lib/python3.11/dist-packages/jinja2/compiler.py in generate(node, environment, name, filename, stream, defer_init, optimized)
#     115         environment, name, filename, stream, defer_init, optimized
#     116     )
# --> 117     generator.visit(node)
#     118
#     119     if stream is None:
#
# /usr/local/lib/python3.11/dist-packages/jinja2/visitor.py in visit(self, node, *args, **kwargs)
#      38
#      39         if f is not None:
# ---> 40             return f(node, *args, **kwargs)
#      41
#      42         return self.generic_visit(node, *args, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/jinja2/compiler.py in visit_Template(self, node, frame)
#     890         self.enter_frame(frame)
#     891         self.pull_dependencies(node.body)
# --> 892         self.blockvisit(node.body, frame)
#     893         self.leave_frame(frame, with_python_scope=True)
#     894         self.outdent()
#
# /usr/local/lib/python3.11/dist-packages/jinja2/compiler.py in blockvisit(self, nodes, frame)
#     447             self.writeline("pass")
#     448             for node in nodes:
# --> 449                 self.visit(node, frame)
#     450         except CompilerExit:
#     451             pass
#
# /usr/local/lib/python3.11/dist-packages/jinja2/visitor.py in visit(self, node, *args, **kwargs)
#      38
#      39         if f is not None:
# ---> 40             return f(node, *args, **kwargs)
#      41
#      42         return self.generic_visit(node, *args, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/jinja2/compiler.py in visit_Output(self, node, frame)
#    1553             if isinstance(item, list):
#    1554                 # A group of constant data to join and output.
# -> 1555                 val = self._output_const_repr(item)
#    1556
#    1557                 if frame.buffer is None:
#
# /usr/local/lib/python3.11/dist-packages/jinja2/compiler.py in _output_const_repr(self, group)
#    1451         source.
#    1452         """
# -> 1453         return repr(concat(group))
#    1454
#    1455     def _output_child_to_const(
#
# KeyboardInterrupt:

# %%
import json
import folium
import time
import random
from shapely.geometry import LineString
from shapely.ops import transform
import pyproj
from IPython.display import display, clear_output

# Constants
TIME_STEP = 0.2  # More frequent updates
ALARM_SPEED_MULTIPLIER = 1.3  # Increase speed boost for alarm cars
NO_ALARM_SPEED_MULTIPLIER = 0.7  # Further slow down cars without alarms
FAST_CAR_SPEED_KMH = 200  # Police car is even faster
FAST_CAR_DELAY = 2  # Starts even sooner

# Load road from GeoJSON
def load_road(file_path):
    with open(file_path, 'r') as file:
        return LineString(json.load(file)['features'][0]['geometry']['coordinates'])

# Coordinate transformation
def transform_coords(geom, from_epsg=4326, to_epsg=25832):
    return transform(pyproj.Transformer.from_crs(from_epsg, to_epsg, always_xy=True).transform, geom)

# Car class
class Car:
    def __init__(self, road, speed_kmh, has_alarm=False, delay_chance=0, start_delay=0):
        self.road = transform_coords(road)
        self.speed_mps = (speed_kmh * 1000 / 3600) * (ALARM_SPEED_MULTIPLIER if has_alarm else NO_ALARM_SPEED_MULTIPLIER if random.randint(0, 100) < delay_chance else 1)
        self.position_m = 0
        self.start_delay = start_delay

    def advance(self):
        self.position_m = min(self.position_m + self.speed_mps * TIME_STEP, self.road.length)

    def get_position(self):
        return transform_coords(self.road.interpolate(self.position_m), from_epsg=25832, to_epsg=4326)

# Run simulation
def run_simulation(geojson_path, speed_kmh=120):
    road = load_road(geojson_path)

    car_a = Car(road, speed_kmh, has_alarm=True)
    car_b = Car(road, speed_kmh, delay_chance=random.randint(10, 50))
    fast_car = Car(road, FAST_CAR_SPEED_KMH, start_delay=FAST_CAR_DELAY)

    icons = {
        car_a: folium.CustomIcon("sample_data/redcar.png", icon_size=(40, 40)),
        car_b: folium.CustomIcon("sample_data/bluecar.png", icon_size=(40, 40)),
        fast_car: folium.CustomIcon("sample_data/policecar.png", icon_size=(50, 50)),
    }

    time_elapsed = 0
    while car_a.position_m < car_a.road.length or car_b.position_m < car_b.road.length:
        if time_elapsed >= fast_car.start_delay:
            fast_car.advance()
        car_a.advance()
        car_b.advance()

        map_center = car_a.get_position()
        m = folium.Map(location=[map_center.y, map_center.x], zoom_start=15, control_scale=True)
        folium.PolyLine([(pt[1], pt[0]) for pt in road.coords], color="blue", weight=3).add_to(m)

        for car in [car_a, car_b, fast_car]:
            folium.Marker(
                location=[car.get_position().y, car.get_position().x], icon=icons[car]
            ).add_to(m)

        m.save("car_simulation.html")
        clear_output(wait=True)
        display(m)

        time_elapsed += TIME_STEP
        time.sleep(0.1)  # Even faster updates

    print("Simulation complete.")

# Run the simulation
run_simulation("sample_data/map.geojson", speed_kmh=120)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1080ae67a1c8> in <cell line: 0>()
#      78
#      79 # Run the simulation
# ---> 80 run_simulation("sample_data/map.geojson", speed_kmh=120)
#
# <ipython-input-9-1080ae67a1c8> in run_simulation(geojson_path, speed_kmh)
#      70         m.save("car_simulation.html")
#      71         clear_output(wait=True)
# ---> 72         display(m)
#      73
#      74         time_elapsed += TIME_STEP
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.11/dist-packages/folium/folium.py in _repr_html_(self, **kwargs)
#     333             self._parent = None
#     334         else:
# --> 335             out = self._parent._repr_html_(**kwargs)
#     336         return out
#     337
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in _repr_html_(self, **kwargs)
#     408     def _repr_html_(self, **kwargs) -> str:
#     409         """Displays the Figure in a Jupyter notebook."""
# --> 410         html = escape(self.render(**kwargs))
#     411         if self.height is None:
#     412             iframe = (
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in render(self, **kwargs)
#     403         """Renders the HTML representation of the element."""
#     404         for name, child in self._children.items():
# --> 405             child.render(**kwargs)
#     406         return self._template.render(this=self, kwargs=kwargs)
#     407
#
# /usr/local/lib/python3.11/dist-packages/folium/folium.py in render(self, **kwargs)
#     415         )
#     416
# --> 417         super().render(**kwargs)
#     418
#     419     def show_in_browser(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/folium/elements.py in render(self, **kwargs)
#      25             figure.header.add_child(CssLink(url), name=name)
#      26
# ---> 27         super().render(**kwargs)
#      28
#      29     def add_css_link(self, name: str, url: str):
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in render(self, **kwargs)
#     734
#     735         for name, element in self._children.items():
# --> 736             element.render(**kwargs)
#
# /usr/local/lib/python3.11/dist-packages/folium/map.py in render(self)
#     411                 f"{self._name} location must be assigned when added directly to map."
#     412             )
# --> 413         super().render()
#     414
#     415
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in render(self, **kwargs)
#     734
#     735         for name, element in self._children.items():
# --> 736             element.render(**kwargs)
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in render(self, **kwargs)
#     731         script = self._template.module.__dict__.get("script", None)
#     732         if script is not None:
# --> 733             figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     734
#     735         for name, element in self._children.items():
#
# /usr/local/lib/python3.11/dist-packages/branca/element.py in __init__(self, template, template_name)
#      66
#      67         if template is not None:
# ---> 68             self._template = Template(template)
#      69         elif template_name is not None:
#      70             self._template = ENV.get_template(template_name)
#
# /usr/local/lib/python3.11/dist-packages/jinja2/environment.py in __new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape, enable_async)
#    1212             enable_async,
#    1213         )
# -> 1214         return env.from_string(source, template_class=cls)
#    1215
#    1216     @classmethod
#
# /usr/local/lib/python3.11/dist-packages/jinja2/environment.py in from_string(self, source, globals, template_class)
#    1109         gs = self.make_globals(globals)
#    1110         cls = template_class or self.template_class
# -> 1111         return cls.from_code(self, self.compile(source), gs, None)
#    1112
#    1113     def make_globals(
#
# /usr/local/lib/python3.11/dist-packages/jinja2/environment.py in compile(self, source, name, filename, raw, defer_init)
#     761             if isinstance(source, str):
#     762                 source_hint = source
# --> 763                 source = self._parse(source, name, filename)
#     764             source = self._generate(source, name, filename, defer_init=defer_init)
#     765             if raw:
#
# /usr/local/lib/python3.11/dist-packages/jinja2/environment.py in _parse(self, source, name, filename)
#     620     ) -> nodes.Template:
#     621         """Internal parsing function used by `parse` and `compile`."""
# --> 622         return Parser(self, source, name, filename).parse()
#     623
#     624     def lex(
#
# /usr/local/lib/python3.11/dist-packages/jinja2/parser.py in __init__(self, environment, source, name, filename, state)
#      60     ) -> None:
#      61         self.environment = environment
# ---> 62         self.stream = environment._tokenize(source, name, filename, state)
#      63         self.name = name
#      64         self.filename = filename
#
# /usr/local/lib/python3.11/dist-packages/jinja2/environment.py in _tokenize(self, source, name, filename, state)
#     670         """
#     671         source = self.preprocess(source, name, filename)
# --> 672         stream = self.lexer.tokenize(source, name, filename, state)
#     673
#     674         for ext in self.iter_extensions():
#
# /usr/local/lib/python3.11/dist-packages/jinja2/lexer.py in tokenize(self, source, name, filename, state)
#     611         """Calls tokeniter + tokenize and wraps it in a token stream."""
#     612         stream = self.tokeniter(source, name, filename, state)
# --> 613         return TokenStream(self.wrap(stream, name, filename), name, filename)
#     614
#     615     def wrap(
#
# /usr/local/lib/python3.11/dist-packages/jinja2/lexer.py in __init__(self, generator, name, filename)
#     335         self.closed = False
#     336         self.current = Token(1, TOKEN_INITIAL, "")
# --> 337         next(self)
#     338
#     339     def __iter__(self) -> TokenStreamIterator:
#
# /usr/local/lib/python3.11/dist-packages/jinja2/lexer.py in __next__(self)
#     389         elif self.current.type is not TOKEN_EOF:
#     390             try:
# --> 391                 self.current = next(self._iter)
#     392             except StopIteration:
#     393                 self.close()
#
# /usr/local/lib/python3.11/dist-packages/jinja2/lexer.py in wrap(self, stream, name, filename)
#     622         every token in a :class:`Token` and converts the value.
#     623         """
# --> 624         for lineno, token, value_str in stream:
#     625             if token in ignored_tokens:
#     626                 continue
#
# /usr/local/lib/python3.11/dist-packages/jinja2/lexer.py in tokeniter(self, source, name, filename, state)
#     704             # tokenizer loop
#     705             for regex, tokens, new_state in statetokens:
# --> 706                 m = regex.match(source, pos)
#     707
#     708                 # if no match we try again with the next rule
#
# KeyboardInterrupt:
